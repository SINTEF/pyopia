# %% [markdown]
# # Imports

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import pyopia.statistics
import pyopia.plotting
import matplotlib.pyplot as plt
from matplotlib import colors
import cmocean
import numpy as np

# %%
filename = 'proc/test-STATS.h5'
roidir = 'export'
pixel_size = 28
path_length = 40

montage = pyopia.statistics.make_montage(filename, pixel_size, roidir,
                 auto_scaler=300, msize=1024)
# Out:
# rofiles: 1986
# reducing particles by factor of 7
# rofiles: 284
# making a montage - this might take some time....
#   0%|          | 0/284 [00:00<?, ?it/s]
#   0%|          | 1/284 [00:07<33:33,  7.12s/it]
#   1%|          | 2/284 [00:08<17:30,  3.73s/it]
#   1%|          | 3/284 [00:09<10:37,  2.27s/it]
#   1%|▏         | 4/284 [00:10<09:50,  2.11s/it]
#   2%|▏         | 5/284 [00:11<07:28,  1.61s/it]
#   2%|▏         | 6/284 [00:12<06:06,  1.32s/it]
#   2%|▏         | 7/284 [00:13<05:12,  1.13s/it]
#   3%|▎         | 8/284 [00:13<04:05,  1.12it/s]
#   3%|▎         | 9/284 [00:16<06:34,  1.44s/it]
#   3%|▎         | 9/284 [00:17<08:56,  1.95s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 6
#       3 pixel_size = 28
#       4 path_length = 40
# ----> 6 montage = pyopia.statistics.make_montage(filename, pixel_size, roidir,
#       7                  auto_scaler=300, msize=1024)
#
# File c:\users\emlynd\documents\github\pyopia\pyopia\statistics.py:426, in make_montage(stats_file, pixel_size, roidir, auto_scaler, msize, maxlength, crop_stats)
#     422 stats.sort_values(by=['major_axis_length'], ascending=False, inplace=True)
#     424 roifiles = gen_roifiles(stats, auto_scaler=auto_scaler)
# --> 426 montage = montage_maker(roifiles, roidir, pixel_size, msize, eyecandy=True)
#     428 return montage
#
# File c:\users\emlynd\documents\github\pyopia\pyopia\statistics.py:331, in montage_maker(roifiles, roidir, pixel_size, msize, brightness, eyecandy)
#     329 plt.imshow(particle_image)
#     330 plt.show()
# --> 331 input()
#     333 # measure the size of this image
#     334 [height, width] = np.shape(particle_image[:, :, 0])
#
# File c:\Users\emlynd\.conda\envs\pyopia\lib\site-packages\ipykernel\kernelbase.py:1175, in Kernel.raw_input(self, prompt)
#    1171 if not self._allow_stdin:
#    1172     raise StdinNotImplementedError(
#    1173         "raw_input was called, but this frontend does not support input requests."
#    1174     )
# -> 1175 return self._input_request(
#    1176     str(prompt),
#    1177     self._parent_ident["shell"],
#    1178     self.get_parent("shell"),
#    1179     password=False,
#    1180 )
#
# File c:\Users\emlynd\.conda\envs\pyopia\lib\site-packages\ipykernel\kernelbase.py:1217, in Kernel._input_request(self, prompt, ident, parent, password)
#    1214             break
#    1215 except KeyboardInterrupt:
#    1216     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1217     raise KeyboardInterrupt("Interrupted by user") from None
#    1218 except Exception:
#    1219     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
pyopia.plotting.montage_plot(montage, pixel_size)
